# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
odhf = pd.read_csv("drive/MyDrive/odhf.csv", encoding = "unicode_escape")

# %%
odhf.head()
# Out:
#   index                           facility_name  ...   latitude   longitude
# 0     1  Advanced Facial & Nasal Surgery Centre  ...        NaN         NaN
# 1    10             Alberta Children's Hospital  ...  51.074582 -114.148426
# 2   100                  Devon General Hospital  ...  53.351493 -113.730785
# 3  1000                          Kimbelee Place  ...  49.177418 -122.864118
# 4  1001             Kimberley Special Care Home  ...  49.689998 -115.989647
#
# [5 rows x 17 columns]

# %%
odhf.isnull().sum()
# Out:
# index                           0
# facility_name                   0
# source_facility_type         1350
# odhf_facility_type              0
# provider                        0
# unit                         7028
# street_no                     594
# street_name                   520
# postal_code                     0
# city                           23
# province                        0
# source_format_str_address    3098
# CSDname                        39
# CSDuid                        484
# Pruid                           0
# latitude                      484
# longitude                     484
# dtype: int64

# %%
odhf.shape
# Out:
# (7033, 17)

# %%
odhf.dtypes
# Out:
# index                         object
# facility_name                 object
# source_facility_type          object
# odhf_facility_type            object
# provider                      object
# unit                          object
# street_no                     object
# street_name                   object
# postal_code                   object
# city                          object
# province                      object
# source_format_str_address     object
# CSDname                       object
# CSDuid                       float64
# Pruid                          int64
# latitude                     float64
# longitude                    float64
# dtype: object

# %%
odhf.describe()
# Out:
#              CSDuid        Pruid     latitude    longitude
# count  6.549000e+03  7033.000000  6549.000000  6549.000000
# mean   3.658963e+06    36.873738    46.783843   -87.380783
# std    1.376972e+06    13.919410     3.188327    19.998356
# min    1.001240e+06    10.000000    42.026259  -139.436000
# 25%    2.467050e+06    24.000000    44.190088  -103.665662
# 50%    3.523008e+06    35.000000    45.841412   -79.476412
# 75%    4.706027e+06    47.000000    49.137768   -73.658541
# max    6.208073e+06    62.000000    69.117411   -52.695163

# %%
odhf.plot(kind='box', subplots=True, legend=False, layout=(2,2))
plt.show()

# %%
odhf.corr()
# Out:
#              CSDuid     Pruid  latitude  longitude
# CSDuid     1.000000  0.999670  0.490791  -0.955376
# Pruid      0.999670  1.000000  0.489172  -0.955011
# latitude   0.490791  0.489172  1.000000  -0.621576
# longitude -0.955376 -0.955011 -0.621576   1.000000

# %%
odhf.describe()
# Out:
#              CSDuid        Pruid     latitude    longitude
# count  6.549000e+03  7033.000000  6549.000000  6549.000000
# mean   3.658963e+06    36.873738    46.783843   -87.380783
# std    1.376972e+06    13.919410     3.188327    19.998356
# min    1.001240e+06    10.000000    42.026259  -139.436000
# 25%    2.467050e+06    24.000000    44.190088  -103.665662
# 50%    3.523008e+06    35.000000    45.841412   -79.476412
# 75%    4.706027e+06    47.000000    49.137768   -73.658541
# max    6.208073e+06    62.000000    69.117411   -52.695163

# %%
odhf.describe(include=['O'])
# Out:
#         index  ...  CSDname
# count    7033  ...     6994
# unique   7033  ...     1390
# top     S1720  ...  Toronto
# freq        1  ...      399
#
# [4 rows x 13 columns]

# %%
type(odhf)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.hist(odhf['odhf_facility_type'], bins=10)
plt.show()

# %%
p1 = odhf.groupby(['odhf_facility_type']).size()
p1


p2 = p1.plot(kind = "bar", xlabel = "Facility Types", title = " Health Care facility types")

# %%
p1 = odhf.groupby(['odhf_facility_type']).size()
p1
# Out:
# odhf_facility_type
# Ambulatory health care services            2227
# Hospitals                                  1140
# Nursing and residential care facilities    3664
# nursing and residential care facilities       2
# dtype: int64

# %%
plt.scatter(odhf['latitude'], odhf['longitude'], color='#B22222', alpha= 0.5, marker='d')
plt.xlabel("X co-ordinates")
plt.ylabel("Y co-ordinates")
plt.title("Plot between X and Y co-ordinates")
plt.show()

# %%
sns.set(style="ticks")
sns.pairplot(odhf, hue="province")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %%
pro_grp = odhf.groupby(['provider']).size()
pro_grp


plot2 = pro_grp.plot(kind = "bar", xlabel = "Provider Type", title = "Provider Types")

# %%
prvn_grp = odhf.groupby(['province']).size()
prvn_grp


plot3 = prvn_grp.plot(kind = "bar", xlabel = "Province Code", title = "Provinces")

# %%
city_grp = odhf.groupby(['city']).size()
city_grp


city_grp.plot(kind = "line", xlabel = "City Names", title = "List of Cities")

# %%
#ggdotchart(odhf, x = "odhf_facility_type", y = "city",

         #  color = "odhf_facility_type",                                # Color by groups

         #  palette = c("#00AFBB", "#E7B800", "#FC4E07"), # Custom color palette

          # sorting = "ascending",                        # Sort value in descending order

           #add = "segments",                             # Add segments from y = 0 to dots

           #ggtheme = theme_pubr()                        # ggplot2 theme

# %%
plt.stem(odhf['city'])

plt.xticks( my_range, odhf['province'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-2fcdb5567943> in <module>()
# ----> 1 plt.stem(odhf['city'])
#       2
#       3 plt.xticks( my_range, odhf['province'])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in stem(linefmt, markerfmt, basefmt, bottom, label, use_line_collection, data, *args)
#    2879         bottom=bottom, label=label,
#    2880         use_line_collection=use_line_collection, **({"data": data} if
# -> 2881         data is not None else {}))
#    2882
#    2883
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
